# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install quarto-cli

# %%
# !quarto render "/content/drive/MyDrive/Colab Notebooks/UNICEF_Sanitation_Colab_Complete.ipynb"
# Out:
# pandoc
#   to: html
#   output-file: UNICEF_Sanitation_Colab_Complete.html
#   standalone: true
#   embed-resources: true
#   section-divs: true
#   html-math-method: mathjax
#   wrap: none
#   default-image-extension: png
#   toc: true
#   toc-depth: 3
#   number-sections: true
#   css:
#     - styles.css
#
# metadata
#   document-css: false
#   link-citations: true
#   date-format: long
#   lang: en
#   title: UNICEF Sanitation
#   subtitle: UNICEF Global Sanitation Access Report (2000–2020)
#   author: 'Gokulnath Amarnathraja - DCU ID: A00011049'
#   date: April 27, 2025
#   theme: materia
#   toc-location: right
#   code-summary: Show Code
#   allow-html: true
#
# [WARNING] Could not fetch resource styles.css
# Output created: UNICEF_Sanitation_Colab_Complete.html
